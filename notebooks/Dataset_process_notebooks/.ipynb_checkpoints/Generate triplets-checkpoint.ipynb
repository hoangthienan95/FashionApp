# %% [markdown]
# ## Generate training image triplets from polyvore data (2 compatible fashion item and 1 not compatible fashion item)

# %%
import pandas as pd
import json
import numpy as np

# %%
DATA_DIR = "../data/polyvore_outfits/"
SUB_DATASET = "disjoint/"
SUB_DATASET_DIR = f"{DATA_DIR}/{SUB_DATASET}"

# %%
def json2df(data):
    df = pd.DataFrame()
    for index, el in enumerate(data):
        for key, val in el.items():
            df.loc[index, key] = val
    return df

# %%
dict_df = pd.read_json(f"{SUB_DATASET_DIR}/train.json").explode(column="items")
dict_df = dict_df.join(pd.DataFrame(dict_df["items"].values.tolist(), index=dict_df.index))
dict_df.item_id = dict_df.item_id.astype("int")
dict_df = dict_df.drop(columns="items")

# %%
item_attrs = pd.read_json(f"{DATA_DIR}/polyvore_item_metadata.json",orient = "index")
item_attrs.head()
# Out:
#            category_id                                         catgeories  \
# 100004189           57
# 100005237           53
# 100007550            4
# 100010397           41
# 100010564           41  [Women's Fashion, Shoes, Pumps, Giuseppe Zanot...
#
#           description                                            related  \
# 100004189
# 100005237
# 100007550
# 100010397
# 100010564              [Giuseppe Zanotti, High heeled footwear, Heel ...
#
#           semantic_category  \
# 100004189        sunglasses
# 100005237       accessories
# 100007550          all-body
# 100010397             shoes
# 100010564             shoes
#
#                                                        title  \
# 100004189
# 100005237
# 100007550
# 100010397
# 100010564  i36033 001 - Décolleté Donna - Scarpe Donna su...
#
#                                               url_name
# 100004189            retro hippie fashion metal lennon
# 100005237      amazon.com 100 imported cashmere gloves
# 100007550        mcq alexander mcqueen tailored tuxedo
# 100010397          nfinity vengeance cheerleading shoe
# 100010564  i36033 001 d%C3%A9collet%C3%A9 donna scarpe

# %%
merged_df = dict_df.merge(item_attrs[["category_id", "semantic_category"]], left_on = "item_id", right_index = True, how = "left")
merged_df.head()
# Out:
#       set_id    item_id  index  category_id semantic_category
# 0  199244701  132621870      1           38              bags
# 0  199244701  153967122      2           46             shoes
# 0  199244701  171169800      3           62         jewellery
# 0  199244701  162799044      4           64         jewellery
# 0  199244701  172538912      5           65         jewellery

# %%
merged_df[["set_id","item_id"]]
# Out:
#           set_id    item_id
# 0      199244701  132621870
# 0      199244701  153967122
# 0      199244701  171169800
# 0      199244701  162799044
# 0      199244701  172538912
# ...          ...        ...
# 16993  205613256  180608937
# 16994  225327855  180383429
# 16994  225327855  201915007
# 16994  225327855  180383429
# 16994  225327855  201915007
#
# [471719 rows x 2 columns]

# %%
merged_df["identifier"] = merged_df[["set_id","index"]].astype("str").apply("_".join, axis=1)

# %%
df = pd.read_table(f"{DATA_DIR}/disjoint/compatibility_train.txt", header=None, skipinitialspace=True)
df = df[0].str.split(" ", expand = True)

df.columns = ["is_compat", *[f"item_{i}" for i in range(1, len(df.columns))]]
df.is_compat = df.is_compat.astype("int")
df.loc[df.is_compat == 0, "item_1":] = df.loc[df.is_compat == 0, "item_1":].shift(periods=-1, axis='columns')
df["outfit_num"] = np.tile(range(int(df.shape[0]/2)), 2)
df
# Out:
#        is_compat       item_1       item_2       item_3       item_4  \
# 0              1  199244701_1  199244701_2  199244701_3  199244701_4
# 1              1  200742384_1  200742384_2  200742384_3  200742384_4
# 2              1  206955877_1  206955877_2  206955877_3  206955877_4
# 3              1  220340816_1  220340816_2  220340816_3  220340816_4
# 4              1  219393187_1  219393187_2  219393187_3  219393187_4
# ...          ...          ...          ...          ...          ...
# 33985          0  218506324_1  221405016_1  206461374_3  218864675_6
# 33986          0  105184990_1  211494606_3  204086912_4  220595501_3
# 33987          0   66630383_1  132553628_1  224927539_2  223480393_3
# 33988          0  149252664_1  224932578_2  205854787_3  206523026_4
# 33989          0  119274863_2  211094404_4         None         None
#
#             item_5       item_6       item_7       item_8 item_9 item_10  \
# 0      199244701_5  199244701_6         None         None   None    None
# 1      200742384_5         None         None         None   None    None
# 2      206955877_5  206955877_6         None         None   None    None
# 3      220340816_5         None         None         None   None    None
# 4      219393187_5         None         None         None   None    None
# ...            ...          ...          ...          ...    ...     ...
# 33985         None         None         None         None   None    None
# 33986         None         None         None         None   None    None
# 33987  219992174_3   85057420_4  195654231_5  206629909_3   None    None
# 33988  212115201_6  218241080_6         None         None   None    None
# 33989         None         None         None         None   None    None
#
#       item_11 item_12 item_13 item_14 item_15 item_16 item_17  outfit_num
# 0        None    None    None    None    None    None    None           0
# 1        None    None    None    None    None    None    None           1
# 2        None    None    None    None    None    None    None           2
# 3        None    None    None    None    None    None    None           3
# 4        None    None    None    None    None    None    None           4
# ...       ...     ...     ...     ...     ...     ...     ...         ...
# 33985    None    None    None    None    None    None     NaN       16990
# 33986    None    None    None    None    None    None     NaN       16991
# 33987    None    None    None    None    None    None     NaN       16992
# 33988    None    None    None    None    None    None     NaN       16993
# 33989    None    None    None    None    None    None     NaN       16994
#
# [33990 rows x 19 columns]

# %%
melted_df = df.melt(id_vars=["is_compat", "outfit_num"], var_name="item", value_name="identifier").query("identifier.notnull()")
melted_df
# Out:
#         is_compat  outfit_num     item    identifier
# 0               1           0   item_1   199244701_1
# 1               1           1   item_1   200742384_1
# 2               1           2   item_1   206955877_1
# 3               1           3   item_1   220340816_1
# 4               1           4   item_1   219393187_1
# ...           ...         ...      ...           ...
# 475683          0       16818  item_14  216771451_14
# 484206          1        8346  item_15  220541340_15
# 501201          0        8346  item_15   220060656_5
# 518196          1        8346  item_16  220541340_16
# 535191          0        8346  item_16   215182419_4
#
# [171870 rows x 4 columns]

# %%
melted_df[["set_id", "index"]] = melted_df["identifier"].str.split("_", expand=True).astype("int")

# %%
len(melted_df.outfit_num.unique())
# Out:
# 16995

# %%
merged_df
# Out:
#           set_id    item_id  index  category_id semantic_category   identifier
# 0      199244701  132621870      1           38              bags  199244701_1
# 0      199244701  153967122      2           46             shoes  199244701_2
# 0      199244701  171169800      3           62         jewellery  199244701_3
# 0      199244701  162799044      4           64         jewellery  199244701_4
# 0      199244701  172538912      5           65         jewellery  199244701_5
# ...          ...        ...    ...          ...               ...          ...
# 16993  205613256  180608937      6           51           scarves  205613256_6
# 16994  225327855  180383429      1           49             shoes  225327855_1
# 16994  225327855  201915007      2            4          all-body  225327855_2
# 16994  225327855  180383429      1           49             shoes  225327855_1
# 16994  225327855  201915007      2            4          all-body  225327855_2
#
# [471719 rows x 6 columns]

# %%
melted_df.query("outfit_num == 0").sort_values(by=["is_compat", "item"])
# Out:
#         is_compat  outfit_num    item   identifier     set_id  index
# 16995           0           0  item_1  219713029_1  219713029      1
# 50985           0           0  item_2  223118810_1  223118810      1
# 84975           0           0  item_3  224078562_3  224078562      3
# 118965          0           0  item_4  222231874_3  222231874      3
# 152955          0           0  item_5  222344225_3  222344225      3
# 186945          0           0  item_6   76483638_7   76483638      7
# 0               1           0  item_1  199244701_1  199244701      1
# 33990           1           0  item_2  199244701_2  199244701      2
# 67980           1           0  item_3  199244701_3  199244701      3
# 101970          1           0  item_4  199244701_4  199244701      4
# 135960          1           0  item_5  199244701_5  199244701      5
# 169950          1           0  item_6  199244701_6  199244701      6

# %%
merged_df
# Out:
#           set_id    item_id  index  category_id semantic_category   identifier
# 0      199244701  132621870      1           38              bags  199244701_1
# 0      199244701  153967122      2           46             shoes  199244701_2
# 0      199244701  171169800      3           62         jewellery  199244701_3
# 0      199244701  162799044      4           64         jewellery  199244701_4
# 0      199244701  172538912      5           65         jewellery  199244701_5
# ...          ...        ...    ...          ...               ...          ...
# 16993  205613256  180608937      6           51           scarves  205613256_6
# 16994  225327855  180383429      1           49             shoes  225327855_1
# 16994  225327855  201915007      2            4          all-body  225327855_2
# 16994  225327855  180383429      1           49             shoes  225327855_1
# 16994  225327855  201915007      2            4          all-body  225327855_2
#
# [471719 rows x 6 columns]

# %%
final_df = melted_df.merge(merged_df, on="identifier").drop_duplicates()

# %%
final_df.semantic_category.unique()
# Out:
# array(['bags', 'shoes', 'jewellery', 'tops', 'hats', 'sunglasses',
#        'all-body', 'accessories', 'bottoms', 'outerwear', 'scarves'],
#       dtype=object)

# %%
final_df.query("outfit_num == 0").sort_values(by=["is_compat", "item"])
# Out:
#         is_compat  outfit_num    item   identifier   set_id_x  index_x  \
# 127201          0           0  item_1  219713029_1  219713029        1
# 94161           0           0  item_2  223118810_1  223118810        1
# 444358          0           0  item_3  224078562_3  224078562        3
# 496627          0           0  item_4  222231874_3  222231874        3
# 400114          0           0  item_5  222344225_3  222344225        3
# 917974          0           0  item_6   76483638_7   76483638        7
# 0               1           0  item_1  199244701_1  199244701        1
# 203150          1           0  item_2  199244701_2  199244701        2
# 390616          1           0  item_3  199244701_3  199244701        3
# 612252          1           0  item_4  199244701_4  199244701        4
# 770852          1           0  item_5  199244701_5  199244701        5
# 893784          1           0  item_6  199244701_6  199244701        6
#
#          set_id_y    item_id  index_y  category_id semantic_category
# 127201  219713029  204656212        1           38              bags
# 94161   223118810  211483114        1           46             shoes
# 444358  224078562  203867196        3           62         jewellery
# 496627  222231874  118116943        3           64         jewellery
# 400114  222344225  179210717        3           65         jewellery
# 917974   76483638   55333264        7            5          all-body
# 0       199244701  132621870        1           38              bags
# 203150  199244701  153967122        2           46             shoes
# 390616  199244701  171169800        3           62         jewellery
# 612252  199244701  162799044        4           64         jewellery
# 770852  199244701  172538912        5           65         jewellery
# 893784  199244701  172312529        6            5          all-body

# %%
compat_df = final_df.query("is_compat == 1").sort_values(by=["outfit_num", "item"])
not_compat_df = final_df.query("is_compat == 0").sort_values(by=["outfit_num", "item"])
compat_df.head()
# Out:
#         is_compat  outfit_num    item   identifier   set_id_x  index_x  \
# 0               1           0  item_1  199244701_1  199244701        1
# 203150          1           0  item_2  199244701_2  199244701        2
# 390616          1           0  item_3  199244701_3  199244701        3
# 612252          1           0  item_4  199244701_4  199244701        4
# 770852          1           0  item_5  199244701_5  199244701        5
#
#          set_id_y    item_id  index_y  category_id semantic_category
# 0       199244701  132621870        1           38              bags
# 203150  199244701  153967122        2           46             shoes
# 390616  199244701  171169800        3           62         jewellery
# 612252  199244701  162799044        4           64         jewellery
# 770852  199244701  172538912        5           65         jewellery

# %%
compat_dict = dict(zip(compat_df.item_id.tolist(), not_compat_df.item_id.tolist()))
compat_dict[171169800]
# Out:
# 203867196

# %%
# !ls ../data/polyvore_outfits/images/| head
# Out:
# 100004189.jpg
# 100005237.jpg
# 100007550.jpg
# 100010397.jpg
# 100010564.jpg
# 100010612.jpg
# 100015328.jpg
# 100015595.jpg
# 100018459.jpg
# 100018712.jpg

# %%
import itertools
all_triplets= []
for outfit_num in compat_df.outfit_num.unique():
    all_triplets += [(item1, item2, compat_dict[item3]) for (item1,item2,item3) in itertools.permutations(compat_df.query(f"outfit_num == {outfit_num}").item_id,3)]

# %% [markdown]
# **final triplet list**

# %%
pd.DataFrame(all_triplets)
# Out:
#                  0          1          2
# 0        132621870  153967122  203867196
# 1        132621870  153967122  194316716
# 2        132621870  153967122  179210717
# 3        132621870  153967122   55333264
# 4        132621870  171169800  211483114
# ...            ...        ...        ...
# 1552177  180608937  175961768  181738641
# 1552178  180608937  162927065   79746902
# 1552179  180608937  162927065  213750382
# 1552180  180608937  162927065  181225408
# 1552181  180608937  162927065  176738366
#
# [1552182 rows x 3 columns]

# %%
pd.DataFrame(all_triplets).to_csv(f"{SUB_DATASET_DIR}/triplets_train_disjoint", sep=" ", header=False, index=False)
